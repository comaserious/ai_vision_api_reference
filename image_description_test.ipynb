# %% [markdown]
# GPT

# %%
from openai import AsyncOpenAI, OpenAI
from anthropic import AsyncAnthropic
from google.genai import types
from google import genai
from mistralai import Mistral

# %%
from dotenv import load_dotenv
import os, base64
from glom import glom
from pydantic import BaseModel, Field
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage
from langgraph.prebuilt import create_react_agent

load_dotenv()
# Out:
# True

# %%
client = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def encode_image(image_path : str):
    with open(image_path, 'rb') as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
image_path = "C:\\test_test\\response_rate_of_image_description\\data\\table_test.png"
    
base64_image = encode_image(image_path)

class ImageDescription(BaseModel):
    category : str = Field(description = "이미지의 카테고리. 4가지 카테고리 : ['figure', 'chart', 'table', 'equation']")
    description : str = Field(description = "Describe image in detail")

# %%
@tool
async def gpt_vision_tool(image_path : str):
    """
    이미지 경로를 통해서 이미지 종류('figure', 'chart', 'table', 'equation')와 설명을 반환하는 툴
    """

    base64_image = encode_image(image_path)

    ext = os.path.splitext(image_path)[1]

    if "." in ext:
        print(f". 있어요. {ext}")
        ext = ext.replace('.', '')

    message_list = [
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": """주어진 이미지를 분석하세요. 이미지 종류('figure', 'chart', 'table', 'equation')와 설명을 반환하세요. 
                    표의 경우 담겨있는 정보를 생략하지 말고 전부 일목요연하게 제공하세요. 설명의 경우 마크다운으로 작성하세요(```markdown 은 사용하지 말고 마크다운 형식으로 작성하세요)
                    수식의 경우 KaTex 포맷으로 작성하세요. $$ $$ or $ $ 형식으로 작성하세요
                    """
                },
                {
                    "type": "input_image",
                    "image_url": f"data:image/{ext};base64,{base64_image}",
                    "detail": "high"
                }
            ]
        }
    ]

    

    response = await client.responses.parse(
        model = "gpt-4.1",
        input = message_list,
        text_format = ImageDescription
    )

    print(response)
    return response

# %%
async def get_image_description_agent(image_path : str, llm):

    system_message = SystemMessage(
    content = f"""
    image_path {image_path}

    당신은 제공받은 이미지 경로를 이용하여 이미지 카테고리('figure', 'chart', 'table', 'equation')과 설명을 이용하여 이미지를 분석하는 봇입니다.

    gpt_vision_tool 툴을 이용하여 이미지 카테고리와 이미지 설명을 반환받으세요

    제공받은 설명을 완벽한 마크다운 형태로 리포맷팅(```markdown 태그는 사용하지 말고 마크다운 형식으로 작성하세요) 하세요.
    """
    )

    tools = [gpt_vision_tool]

    agent = create_react_agent(
        llm,
        tools,
        prompt = system_message
    )

    return agent

# %%
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import stream_graph

# %%
llm = ChatOpenAI(model="gpt-4.1", temperature=0)
agent = await get_image_description_agent(image_path, llm)

# %%
inputs = {
    "messages" : [
        ("user", "주어진 이미지를 분석하세요")
    ]
}

config = RunnableConfig(
    recursion_limit=100
)

# %%
async for chunk_msg, metadata in agent.astream(inputs, config , stream_mode="messages"):
    curr_node = metadata['langgraph_node']
    print(f"Node : {curr_node}")
    print(f"chunk_msg : {chunk_msg}")
    print(f"metadata : {metadata}")
# Out:
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_yZDDRB1d65cVdUf3xiipZe62', 'function': {'arguments': '', 'name': 'gpt_vision_tool'}, 'type': 'function'}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' tool_calls=[{'name': 'gpt_vision_tool', 'args': {}, 'id': 'call_yZDDRB1d65cVdUf3xiipZe62', 'type': 'tool_call'}] tool_call_chunks=[{'name': 'gpt_vision_tool', 'args': '', 'id': 'call_yZDDRB1d65cVdUf3xiipZe62', 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '{"', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}] tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'image', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'image', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'image', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_path', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_path', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_path', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":"', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '":"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '":"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'C', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'C', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'C', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ':\\\\', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': ':\\\\', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': ':\\\\', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'test', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'test', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'test', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_test', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_test', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_test', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '\\\\', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '\\\\', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '\\\\', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'response', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'response', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'response', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_rate', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_rate', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_rate', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_of', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_of', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_of', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_image', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_image', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_image', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_description', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_description', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_description', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '\\\\', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '\\\\', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '\\\\', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'data', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'data', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'data', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '\\\\', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '\\\\', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '\\\\', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'table', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': 'table', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'table', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_test', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '_test', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '_test', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '.png', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '.png', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '.png', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '"}', 'name': None}, 'type': None}]} response_metadata={} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16' invalid_tool_calls=[{'name': None, 'args': '"}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '"}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={} response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_51e1070cf2'} id='run--80b0c910-20eb-4c36-a19a-2fc28db42d16'
# metadata : {'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'checkpoint_ns': 'agent:f947a6ec-6259-d9e1-6024-ac303c41c1e6', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# . 있어요. .png
# Node : tools
# chunk_msg : content='Error: AttributeError("\'coroutine\' object has no attribute \'output_parsed\'")\n Please fix your mistakes.' name='gpt_vision_tool' id='dbc639ef-47da-4ad7-9dce-ffc96890487b' tool_call_id='call_yZDDRB1d65cVdUf3xiipZe62' status='error'
# metadata : {'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('branch:to:tools',), 'langgraph_path': ('__pregel_pull', 'tools'), 'langgraph_checkpoint_ns': 'tools:39e1ded6-9e18-a6d8-50de-09818345755f'}
# c:\Users\COM-NMOIM\miniforge3\envs\graph-module\Lib\typing.py:1696: RuntimeWarning: coroutine 'AsyncResponses.parse' was never awaited
#   return hash(frozenset(self.__args__))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Node : agent
# chunk_msg : content='' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='이미' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='지' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 분석' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 도' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='중' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 오류' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='가' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 발생' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='했습니다' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='.' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 다시' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 시' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='도' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='하거나' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 이미지' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 경' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='로' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 및' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 파일' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='이' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 올' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='바' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='른' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='지' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 확인' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='해' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content=' 주세요' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='.' additional_kwargs={} response_metadata={} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# Node : agent
# chunk_msg : content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_51e1070cf2'} id='run--45563496-72cc-49d3-9d03-5347d94b7dba'
# metadata : {'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'checkpoint_ns': 'agent:9e928071-59d0-4c11-1ef8-121e35c74e31', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
